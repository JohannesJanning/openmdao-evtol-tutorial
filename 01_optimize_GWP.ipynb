# %% [markdown]
# # GWP Optimization (Notebook)
#
# Problem Formulation: run an OpenMDAO optimization minimizing GWP and save a post-optimization Excel report.

# %%
# Cell 1: Imports and JAX/Path setup (Binder compatible)
import os
import sys
import time
import numpy as np

# Binder-friendly JAX settings
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'
os.environ['JAX_ENABLE_X64'] = '1'

# Ensure local imports work in cloud notebooks
sys.path.append(os.getcwd())

import jax
import openmdao.api as om

# optional: persistent jax compilation cache (local folder)
ROOT = os.getcwd()
jax.config.update('jax_compilation_cache_dir', os.path.join(ROOT, 'jax_cache'))
try:
    jax.config.update('jax_enable_x64', True)
except Exception:
    pass

import src.parameters as parameters
from src.optimizer.eVTOL_group import eVTOLGroup
from src.analysis.evaluation_model import full_model_evaluation, write_results_to_excel

print('Environment and imports ready')
# Out:
# Environment and imports ready

# %%
# Cell 2: Design variable initialization (starting point)
x0 = np.array([15.0, 1.7025, 1.5511, 1.6868, 400.0, 1.0], dtype=float)
x0
# Out:
# array([ 15.    ,   1.7025,   1.5511,   1.6868, 400.    ,   1.    ])

# %%
# Cell 3: OpenMDAO Problem setup (build the problem)
prob = om.Problem(model=eVTOLGroup(parameters=parameters))

# Independent variables
iv = om.IndepVarComp()
iv.add_output('b', val=float(x0[0]))
iv.add_output('c', val=float(x0[1]))
iv.add_output('r_cruise', val=float(x0[2]))
iv.add_output('r_hover', val=float(x0[3]))
iv.add_output('rho_bat', val=float(x0[4]))
iv.add_output('c_charge', val=float(x0[5]))
prob.model.add_subsystem('iv', iv, promotes=['*'])

# Small ExecComp constraints (mirrors script)
cons_expr = (
    'c1 = b - rotor_spacing',
    'c2 = 15.0 - vertiport_span',
    'c3 = 5700.0 - MTOM',
    'c4 = 129.0 - V_cruise',
    'c5 = 129.0 - V_climb',
)
cons_comp = om.ExecComp('\n'.join(cons_expr),
                       b=15.0,
                       rotor_spacing=1.0,
                       vertiport_span=1.0,
                       MTOM=1500.0,
                       V_cruise=50.0,
                       V_climb=10.0)
prob.model.add_subsystem('cons_comp', cons_comp)

# Connections
prob.model.connect('rotor_spacing', 'cons_comp.rotor_spacing')
prob.model.connect('vertiport_span', 'cons_comp.vertiport_span')
prob.model.connect('b', 'cons_comp.b')
prob.model.connect('mtom.MTOM', 'cons_comp.MTOM')
prob.model.connect('V_cruise', 'cons_comp.V_cruise')
prob.model.connect('V_climb', 'cons_comp.V_climb')

# Objective: GWP (as in script)
prob.model.add_objective('GWP_annual_ops', ref=52000.0)

# Constraints and design vars (same bounds/scaling)
prob.model.add_constraint('cons_comp.c1', lower=0.0, ref=1.0)
prob.model.add_constraint('vertiport_span', upper=15.0, ref=1.0)
prob.model.add_constraint('MTOM', upper=5700.0, ref=2000.0)
prob.model.add_constraint('V_cruise', upper=129.0, ref=100.0)
prob.model.add_constraint('V_climb', upper=129.0, ref=100.0)

prob.model.add_design_var('b', lower=6.0, upper=15.0, ref0=6.0, ref=15.0)
prob.model.add_design_var('c', lower=1.0, upper=2.5, ref0=1.0, ref=2.5)
prob.model.add_design_var('r_cruise', lower=0.6, upper=2.5, ref0=0.6, ref=2.5)
prob.model.add_design_var('r_hover', lower=0.6, upper=2.0, ref0=0.6, ref=2.0)
prob.model.add_design_var('rho_bat', lower=200.0, upper=400.0, ref0=200.0, ref=400.0)
prob.model.add_design_var('c_charge', lower=1.0, upper=4.0, ref0=1.0, ref=4.0)

# Driver setup (SLSQP)
prob.driver = om.ScipyOptimizeDriver()
prob.driver.options['optimizer'] = 'SLSQP'
prob.driver.options['tol'] = 1e-6
prob.driver.options['disp'] = True
prob.driver.declare_coloring() if hasattr(prob.driver, 'declare_coloring') else None

# Finalize setup and initialize values
prob.setup()
prob.set_val('b', x0[0])
prob.set_val('c', x0[1])
prob.set_val('r_cruise', x0[2])
prob.set_val('r_hover', x0[3])
prob.set_val('rho_bat', x0[4])
prob.set_val('c_charge', x0[5])

print('Problem built and ready')
# Out:
# Problem built and ready

# %%
# Cell 4: Run the optimization
t0 = time.time()
try:
    prob.run_driver()
except Exception as exc:
    print('Optimization failed:', exc)
    raise
t1 = time.time()
print(f'Elapsed (s): {t1-t0:.1f}')
# Out:
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/utils/relevance.py:1234: OpenMDAOWarning:The top level group has a nonlinear solver that computes gradients, so the entire model will be included in the optimization iteration.
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# No coloring was computed successfully.
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 1 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 1 iterations
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/utils/coloring.py:428: DerivativesWarning:Coloring was deactivated.  Improvement of 0.0% was less than min allowed (5.0%).
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.987718343759213
#             Iterations: 4
#             Function evaluations: 4
#             Gradient evaluations: 4
# Optimization Complete
# -----------------------------------
# Elapsed (s): 1.5

# %%
# Cell 5: Extract results and run full model evaluation, then write Excel
def sval(name):
    try:
        return float(np.asarray(prob.get_val(name)).item())
    except Exception:
        return None

b_opt = sval('b')
c_opt = sval('c')
r_cruise_opt = sval('r_cruise')
r_hover_opt = sval('r_hover')
rho_bat_opt = sval('rho_bat')
c_charge_opt = sval('c_charge')

print('Optimal design vector:')
print([b_opt, c_opt, r_cruise_opt, r_hover_opt, rho_bat_opt, c_charge_opt])
# Out:
# Optimal design vector:
# [14.999999999999998, 1.717824959594271, 1.568581736157313, 1.5668155750605908, 400.0, 1.0]

# %%
# 2. EVALUATION (Only once!)
# We use the optimized variables to get the final results dictionary
model_results, comparison_table = full_model_evaluation(
    b_opt, c_opt, r_cruise_opt, r_hover_opt, rho_bat_opt, c_charge_opt, parameters
)

# Define your baseline for the comparison logic
baseline_vector = [14.999999999999998, 1.717824959594271, 1.568581736157313, 1.5668155750605908, 400.0, 1.0]

# 3. STORAGE & EXPORT
import importlib
import src.analysis.evaluation_model as evaluation_model
importlib.reload(evaluation_model)
from src.analysis.evaluation_model import write_results_to_excel, display_model_dashboard

# Save to Excel - Pass the comparison_table here so the Excel has the data
out_path, df_results = write_results_to_excel(
    results_dict=model_results,
    comparison_list=comparison_table,
    mode='GWP',
    filename='optimized_results_GWP.xlsx',
    baseline=baseline_vector
)

# 4. VISUAL DASHBOARD
print("-" * 30)
print("  OPTIMIZED DESIGN DASHBOARD")
print("-" * 30)
# Make sure display_model_dashboard is updated to handle the 'baseline' argument
display_model_dashboard(model_results, baseline=baseline_vector)

# 5. DOWNLOAD LINK
from IPython.display import FileLink, display as ipy_display
if os.path.exists(out_path):
    print("\nDownload full Excel report:")
    ipy_display(FileLink(out_path))
# Out:
# Results written to: src/results/GWP/optimized_results_GWP.xlsx
# ------------------------------
#   OPTIMIZED DESIGN DASHBOARD
# ------------------------------
# <style type="text/css">
# #T_15258 th {
#   background-color: #f2f2f2;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #666;
#   text-align: center;
# }
# #T_15258 td.row0 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row1 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row2 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row3 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row4 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row5 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row6 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row7 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row8 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row9 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row10 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row11 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row12 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row13 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row14 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row15 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row16 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row17 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row18 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row19 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row20 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row21 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row22 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row23 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row24 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row25 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row26 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row27 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row28 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row29 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row30 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row31 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row32 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row33 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row34 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row35 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row36 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row37 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row38 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row39 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row40 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row41 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row42 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row43 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row44 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row45 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row46 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row47 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row48 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row49 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row50 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row51 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row52 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row53 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row54 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row55 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row56 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row57 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row58 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row59 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row60 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row61 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row62 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row63 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row64 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row65 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row66 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row67 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row68 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row69 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row70 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row71 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row72 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row73 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row74 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row75 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row76 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row77 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row78 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row79 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row80 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row81 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row82 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row83 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row84 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row85 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row86 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row87 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row88 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row89 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row90 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row91 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row92 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row93 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row94 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row95 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row96 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row97 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row98 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row99 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row100 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row101 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row102 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row103 {
#   border-top: 1px solid #eee;
# }
# #T_15258 td.row104 {
#   border-top: 3px solid #444;
# }
# #T_15258 td.row105 {
#   border-top: 1px solid #eee;
# }
# #T_15258_row0_col0, #T_15258_row0_col1, #T_15258_row0_col4, #T_15258_row1_col1, #T_15258_row1_col4, #T_15258_row2_col1, #T_15258_row2_col4, #T_15258_row3_col1, #T_15258_row3_col4, #T_15258_row4_col1, #T_15258_row4_col4, #T_15258_row5_col1, #T_15258_row5_col4, #T_15258_row6_col0, #T_15258_row6_col1, #T_15258_row6_col4, #T_15258_row7_col1, #T_15258_row7_col4, #T_15258_row8_col1, #T_15258_row8_col4, #T_15258_row9_col1, #T_15258_row9_col4, #T_15258_row10_col1, #T_15258_row10_col4, #T_15258_row11_col1, #T_15258_row11_col4, #T_15258_row12_col1, #T_15258_row12_col4, #T_15258_row13_col1, #T_15258_row13_col4, #T_15258_row14_col1, #T_15258_row14_col4, #T_15258_row15_col0, #T_15258_row15_col1, #T_15258_row15_col4, #T_15258_row16_col1, #T_15258_row16_col4, #T_15258_row17_col1, #T_15258_row17_col4, #T_15258_row18_col1, #T_15258_row18_col4, #T_15258_row19_col0, #T_15258_row19_col1, #T_15258_row19_col4, #T_15258_row20_col1, #T_15258_row20_col4, #T_15258_row21_col1, #T_15258_row21_col4, #T_15258_row22_col1, #T_15258_row22_col4, #T_15258_row23_col1, #T_15258_row23_col4, #T_15258_row24_col1, #T_15258_row24_col4, #T_15258_row25_col1, #T_15258_row25_col4, #T_15258_row26_col1, #T_15258_row26_col4, #T_15258_row27_col1, #T_15258_row27_col4, #T_15258_row28_col1, #T_15258_row28_col4, #T_15258_row29_col1, #T_15258_row29_col4, #T_15258_row30_col1, #T_15258_row30_col4, #T_15258_row31_col1, #T_15258_row31_col4, #T_15258_row32_col0, #T_15258_row32_col1, #T_15258_row32_col4, #T_15258_row33_col1, #T_15258_row33_col4, #T_15258_row34_col1, #T_15258_row34_col4, #T_15258_row35_col0, #T_15258_row35_col1, #T_15258_row35_col4, #T_15258_row36_col1, #T_15258_row36_col4, #T_15258_row37_col1, #T_15258_row37_col4, #T_15258_row38_col1, #T_15258_row38_col4, #T_15258_row39_col1, #T_15258_row39_col4, #T_15258_row40_col1, #T_15258_row40_col4, #T_15258_row41_col1, #T_15258_row41_col4, #T_15258_row42_col1, #T_15258_row42_col4, #T_15258_row43_col0, #T_15258_row43_col1, #T_15258_row43_col4, #T_15258_row44_col1, #T_15258_row44_col4, #T_15258_row45_col1, #T_15258_row45_col4, #T_15258_row46_col1, #T_15258_row46_col4, #T_15258_row47_col1, #T_15258_row47_col4, #T_15258_row48_col1, #T_15258_row48_col4, #T_15258_row49_col1, #T_15258_row49_col4, #T_15258_row50_col1, #T_15258_row50_col4, #T_15258_row51_col1, #T_15258_row51_col4, #T_15258_row52_col1, #T_15258
# Download full Excel report:
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/src/results/GWP/optimized_results_GWP.xlsx
