# %% [markdown]
# # eVTOL Multidisciplinary Design Optimization (MDO)
#
# **Objective: Minimize annual global warming potential (GWP) [kg CO2e]**
#
# ___Note on Binder Stability: JAX requires an initial "warm-up" period to compile the physics equations into machine code. If the kernel restarts on the first attempt, please run the cells again; subsequent runs will be significantly faster due to the persistent JAX compilation cache.___

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Environment Setup

# %%
# Imports
import os
import sys
import time
import numpy as np
import src.parameters as parameters
from src.optimizer.eVTOL_group import eVTOLGroup
from src.analysis.evaluation_model import full_model_evaluation
import importlib
import src.analysis.evaluation_model as evaluation_model
from src.analysis.evaluation_model import write_results_to_excel, display_model_dashboard

# Binder-friendly JAX settings - JAX allows for automatic differentiation, just-in-time compilation, and GPU/TPU acceleration
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'
os.environ['JAX_ENABLE_X64'] = '1'

# Ensure local imports work in cloud notebooks
sys.path.append(os.getcwd())

import jax
import openmdao.api as om

# persistent jax compilation cache
ROOT = os.getcwd()
jax.config.update('jax_compilation_cache_dir', os.path.join(ROOT, 'jax_cache'))
try:
    jax.config.update('jax_enable_x64', True)
except Exception:
    pass



print('Environment and imports ready')
# Out:
# Environment and imports ready

# %% [markdown]
# ---

# %% [markdown]
# ## 2. OpenMDAO Optimizaiton Problem setup (building the problem)

# %%
# OpenMDAO Problem setup (build the problem)
prob = om.Problem(model=eVTOLGroup(parameters=parameters))

# %% [markdown]
# ### 2.1 Design Variables (define the design space)

# %%
# Design Variables (Independent variables) - creating a "component" that holds our design variables
# what the optimizer is allowed to touch to find the best design
# We provide "placeholder" initial values just to define the variables (they will be overwritten in the opt intializaiton by x(0))
iv = om.IndepVarComp()
iv.add_output('b', val=15.0) 
iv.add_output('c', val=1.0)
iv.add_output('r_cruise', val=1.0)
iv.add_output('r_hover', val=1.0)
iv.add_output('rho_bat', val=400.0)
iv.add_output('c_charge', val=2.0)
prob.model.add_subsystem('iv', iv, promotes=['*'])

# Design Variables bounds (and set scaling/pre-conditioning)
# ref: normalize variables of different magnitudes (e.g., 1.5m vs 400 Wh/kg) to a common 0 to 1 scale for smooth opt
prob.model.add_design_var('b', lower=6.0, upper=15.0, ref0=6.0, ref=15.0)
prob.model.add_design_var('c', lower=1.0, upper=2.5, ref0=1.0, ref=2.5)
prob.model.add_design_var('r_cruise', lower=0.6, upper=2.5, ref0=0.6, ref=2.5)
prob.model.add_design_var('r_hover', lower=0.6, upper=2.0, ref0=0.6, ref=2.0)
prob.model.add_design_var('rho_bat', lower=200.0, upper=400.0, ref0=200.0, ref=400.0)
prob.model.add_design_var('c_charge', lower=1.0, upper=4.0, ref0=1.0, ref=4.0)

# %% [markdown]
# ### 2.2 Constraints (setting boundaries)

# %%
# Constraints: Setting the constraints - creating a "component" that holds our constraints in OpenMDAO

# computation for the constraints component with initial values (these will be overwritten by the optimizer)
cons_comp = om.ExecComp('c1 = b - rotor_spacing',
                       b=15.0,
                       rotor_spacing=1.0)
prob.model.add_subsystem('cons_comp', cons_comp)

# connecting the constraint with the model
prob.model.connect('rotor_spacing', 'cons_comp.rotor_spacing')
prob.model.connect('b', 'cons_comp.b')

# The Enforcer: Constraints and design vars (scaling for the margins of the constraints)
prob.model.add_constraint('cons_comp.c1', lower=0.0, ref=1.0)
prob.model.add_constraint('vertiport_span', upper=15.0, ref=1.0)
prob.model.add_constraint('MTOM', upper=1500.0, ref=2000.0)
prob.model.add_constraint('V_cruise', upper=129.0, ref=100.0)
prob.model.add_constraint('V_climb', upper=129.0, ref=100.0)

# %% [markdown]
# ### 2.3 Objective (defining the goal)

# %%
# Optimization objective:
# negative ref (ref = -x) to maximize, positive ref (ref = x) to minimize

prob.model.add_objective('GWP_annual_ops', ref=50000.0)

# %% [markdown]
# ### 2.4 Optimizaiton Driver (setting up the engine)

# %%
# Driver setup (SLSQP) (Sequential Least Squares Programming) 
# gradient-based optimization algorithm that handles nonlinear problems with constraints effectively
# tol = tolerance for convergence (stop condition)
# disp = display optimization output, 
# declare_coloring = tells OpenMDAO to analyze which variables don't affect each other so it can calculate derivatives in parallel 
#   (enable sparsity pattern for efficient derivatives)

prob.driver = om.ScipyOptimizeDriver()
prob.driver.options['optimizer'] = 'SLSQP'
prob.driver.options['tol'] = 1e-6
prob.driver.options['disp'] = True
prob.driver.declare_coloring() if hasattr(prob.driver, 'declare_coloring') else None

# Initialization
# Gradient-based opt is iterative, 
# they need a starting point in the "design space" to begin searching for the optimum.
# the values are based on pre-SLSQP evelutionary optimizaiton and manual iteration

x0 = np.array([15.0, 1.7025, 1.5511, 1.6868, 400.0, 1.0], dtype=float)

# Finalize setup and initialize values
# prob.setup(): checks that all 'connect' statements actually go to real variables 
# - if made a typo in a variable name, this is where the code will crash
# prob.set_val(): initializes the values of the design variables to the starting point (x0) for the optimization

prob.setup()
prob.set_val('b', x0[0])
prob.set_val('c', x0[1])
prob.set_val('r_cruise', x0[2])
prob.set_val('r_hover', x0[3])
prob.set_val('rho_bat', x0[4])
prob.set_val('c_charge', x0[5])

print('Problem built and ready')
# Out:
# Problem built and ready

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Run the Optimization

# %%
# stopwatch for optimization time
t0 = time.time()

# prob.run_driver(): runs the optimization driver, which iteratively calls the model to evaluate the objective and constraints,
# and uses the results to update the design variables until convergence is achieved or an error occurs.

try:
    prob.run_driver()
except Exception as exc:
    print('Optimization failed:', exc)
    raise
t1 = time.time()
print(f'Elapsed (s): {t1-t0:.1f}')
# Out:
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/utils/relevance.py:1234: OpenMDAOWarning:The top level group has a nonlinear solver that computes gradients, so the entire model will be included in the optimization iteration.
# NL: Newton 0 ; 1607.86791 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 934.279776 0.581067495
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 2 ; 9.31626644e-05 5.79417402e-08
# NL: Newton Converged
# No coloring was computed successfully.
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 1 iterations
# NL: Newton 0 ;
-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 8.00743131e-08 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 5.20978539e-13 6.50618806e-06
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 8.00723396e-09 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 0 0
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.44738794e-10 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.3437142e-13 0.000526986679
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.95735375e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 5.08422995e-13 1.02559353e-06
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.4616175e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 9.52869335e-13 2.13570378e-06
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.46145837e-08 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.3437142e-13 5.25324683e-06
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.46075654e-09 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 5.68434189e-13 0.000127429996
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.46161103e-10 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 3.41060513e-13 0.000764433543
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.44221431e-11 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.46458442e-11 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.81994707e-12 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 1.16077546e-12 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 9.09494702e-13 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 9.09494702e-13 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 1.19128835e-06 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 4.54747351e-13 3.81727355e-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 5.69359775e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 4.58286294e-13 8.04915124e-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.95051574e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 0 0
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 1.5132165e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 0 0
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.18714658e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.3437142e-13 5.59740185e-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.76843264e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.3437142e-13 6.21933421e-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.7684709e-08 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 0 0
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.7688415e-09 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 9.77971157e-13 0.000259488534
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.75794088e-10 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 5.68434189e-14 0.000151262142
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.10666582e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 5.68434189e-14 1.82972428e-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.79600761e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.3437142e-13 8.38235988e-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.79603761e-08 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.3437142e-13 8.38226993e-06
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.79561444e-09 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 0 0
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.79625534e-10 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 4.58286294e-13 0.00163892863
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.79217413e-11 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.96633415e-11 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.21554985e-12 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.54747351e-13 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.54747351e-13 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 4.54747351e-13 1
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.5053986e-06 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.3437142e-13 9.354656e-08
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.25485948e-06 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 3.26540581e-13 1.44816377e-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.25485242e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 5.20978539e-13 2.31047732e-06
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.25476925e-08 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 9.71340767e-13 4.30793867e-05
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.25454578e-09 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 5.08422995e-13 0.000225510167
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.25577734e-10 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 5.68434189e-14 0.00025199038
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 2.80537242e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 5.08422995e-13 1.81231908e-06
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 0.382821055 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 3.12179632e-05 8.15471426e-05
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 2 ; 2.54211497e-13 6.64047846e-13
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 0.344657309 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.52979466e-05 7.34002907e-05
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 2 ; 5.4817808e-13 1.59050183e-12
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 0.0344482704 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.51919118e-07 7.31296856e-06
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 2 ; 2.27373675e-13 6.60043807e-12
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 0.00344465259 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.51839083e-09 7.31101544e-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 0.000344463514 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 2.50122024e-11 7.26120513e-08
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.44463336e-05 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 3.93822758e-13 1.14329369e-08
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 0.034712528 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 1.42802037e-07 4.11384723e-06
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 2 ; 0 0
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 0.0312405683 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 1.15664989e-07 3.70239708e-06
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 2 ; 5.68434189e-14 1.81953857e-12
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 0.00312410728 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 1.15778676e-09 3.70597631e-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 0.000312411232 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 1.18234311e-11 3.784573e-08
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.12411285e-05 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 4.58286294e-13 1.46693258e-08
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.12411225e-06 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 5.1159077e-13 1.63755566e-07
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.12410196e-07 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 0 0
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.12408318e-08 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 0 0
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.12474372e-09 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 0 0
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.12314208e-10 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 4.54747351e-13 0.0014560572
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 3.18968911e-11 1
# NL: Newton Converged
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.1186179055851961
#             Iterations: 67
#             Function evaluations: 410
#             Gradient evaluations: 63
# Optimization FAILED.
# Positive directional derivative for linesearch
# -----------------------------------
# Elapsed (s): 41.9

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Data Extraction

# %%
# - sval: A helper to safely extract scalar values from the OpenMDAO solver.
# - b_opt...c_charge_opt: Capturing the "Winning Design" into standard variables.
# - Print: Displaying the final Design Vector for the optimized eVTOL

def sval(name):
    try:
        return float(np.asarray(prob.get_val(name)).item())
    except Exception:
        return None

b_opt = sval('b')
c_opt = sval('c')
r_cruise_opt = sval('r_cruise')
r_hover_opt = sval('r_hover')
rho_bat_opt = sval('rho_bat')
c_charge_opt = sval('c_charge')

print('Optimal design vector:')
print([b_opt, c_opt, r_cruise_opt, r_hover_opt, rho_bat_opt, c_charge_opt])
# Out:
# Optimal design vector:
# [15.0, 1.0514099951465894, 0.8321672729518137, 1.3708452933735236, 400.0, 1.0000000000523221]

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Design Results

# %%
# 1. full_model_evaluation: Generates a deep-dive dataset for the winning design.
# 2. baseline_vector: Used to calculate "Optimization Gain" (Best vs. Standard).
# 3. Excel & Dashboard: Exports results for stakeholders and displays key performance metrics.

# post-optimization evaluation to get the full set of performance metrics for the optimized design
model_results, comparison_table = full_model_evaluation(
    b_opt, c_opt, r_cruise_opt, r_hover_opt, rho_bat_opt, c_charge_opt, parameters
)

# Define your baseline for the comparison logic
baseline_vector = [15.0, 1.717984604028126, 1.5684475976845202, 1.5667718019064605, 400.0, 1.0]

# Generates a detailed Excel report containing the full model
importlib.reload(evaluation_model)
out_path, df_results = write_results_to_excel(
    results_dict=model_results,
    comparison_list=comparison_table,
    mode='GWP',
    filename='optimized_results_GWP.xlsx',
    baseline=baseline_vector
)

# visual dashboard for the optimized design
print("-" * 30)
print("  OPTIMIZED DESIGN DASHBOARD")
print("-" * 30)
# Make sure display_model_dashboard is updated to handle the 'baseline' argument
display_model_dashboard(model_results, baseline=baseline_vector)
# Out:
# Results written to: src/results/GWP/optimized_results_GWP.xlsx
# ------------------------------
#   OPTIMIZED DESIGN DASHBOARD
# ------------------------------
# <style type="text/css">
# #T_6b8ce th {
#   background-color: #f2f2f2;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #666;
#   text-align: center;
# }
# #T_6b8ce td.row0 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row1 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row2 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row3 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row4 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row5 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row6 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row7 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row8 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row9 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row10 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row11 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row12 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row13 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row14 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row15 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row16 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row17 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row18 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row19 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row20 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row21 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row22 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row23 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row24 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row25 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row26 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row27 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row28 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row29 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row30 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row31 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row32 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row33 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row34 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row35 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row36 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row37 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row38 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row39 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row40 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row41 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row42 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row43 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row44 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row45 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row46 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row47 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row48 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row49 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row50 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row51 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row52 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row53 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row54 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row55 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row56 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row57 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row58 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row59 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row60 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row61 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row62 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row63 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row64 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row65 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row66 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row67 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row68 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row69 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row70 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row71 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row72 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row73 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row74 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row75 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row76 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row77 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row78 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row79 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row80 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row81 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row82 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row83 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row84 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row85 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row86 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row87 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row88 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row89 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row90 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row91 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row92 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row93 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row94 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row95 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row96 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row97 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row98 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row99 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row100 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row101 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row102 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row103 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce td.row104 {
#   border-top: 3px solid #444;
# }
# #T_6b8ce td.row105 {
#   border-top: 1px solid #eee;
# }
# #T_6b8ce_row0_col0, #T_6b8ce_row0_col1, #T_6b8ce_row0_col4, #T_6b8ce_row1_col1, #T_6b8ce_row1_col4, #T_6b8ce_row2_col1, #T_6b8ce_row2_col4, #T_6b8ce_row3_col1, #T_6b8ce_row3_col4, #T_6b8ce_row4_col1, #T_6b8ce_row4_col4, #T_6b8ce_row5_col1, #T_6b8ce_row5_col4, #T_6b8ce_row6_col0, #T_6b8ce_row6_col1, #T_6b8ce_row6_col4, #T_6b8ce_row7_col1, #T_6b8ce_row7_col4, #T_6b8ce_row8_col1, #T_6b8ce_row8_col4, #T_6b8ce_row9_col1, #T_6b8ce_row9_col4, #T_6b8ce_row10_col1, #T_6b8ce_row10_col4, #T_6b8ce_row11_col1, #T_6b8ce_row11_col4, #T_6b8ce_row12_col1, #T_6b8ce_row12_col4, #T_6b8ce_row13_col1, #T_6b8ce_row13_col4, #T_6b8ce_row14_col1, #T_6b8ce_row14_col4, #T_6b8ce_row15_col0, #T_6b8ce_row15_col1, #T_6b8ce_row15_col4, #T_6b8ce_row16_col1, #T_6b8ce_row16_col4, #T_6b8ce_row17_col1, #T_6b8ce_row17_col4, #T_6b8ce_row18_col1, #T_6b8ce_row18_col4, #T_6b8ce_row19_col0, #T_6b8ce_row19_col1, #T_6b8ce_row19_col4, #T_6b8ce_row20_col1, #T_6b8ce_row20_col4, #T_6b8ce_row21_col1, #T_6b8ce_row21_col4, #T_6b8ce_row22_col1, #T_6b8ce_row22_col4, #T_6b8ce_row23_col1, #T_6b8ce_row23_col4, #T_6b8ce_row24_col1, #T_6b8ce_row24_col4, #T_6b8ce_row25_col1, #T_6b8ce_row25_col4, #T_6b8ce_row26_col1, #T_6b8ce_row26_col4, #T_6b8ce_row27_col1, #T_6b8ce_row27_col4, #T_6b8ce_row28_col1, #T_6b8ce_row28_col4, #T_6b8ce_row29_col1, #T_6b8ce_row29_col4, #T_6b8ce_row30_col1, #T_6b8ce_row30_col4, #T_6b8ce_row31_col1, #T_6b8ce_row31_col4, #T_6b8ce_row32_col0, #T_6b8ce_row32_col1, #T_6b8ce_row32_col4, #T_6b8ce_row33_col1, #T_6b8ce_row33_col4, #T_6b8ce_row34_col1, #T_6b8ce_row34_col4, #T_6b8ce_row35_col0, #T_6b8ce_row35_col1, #T_6b8ce_row35_col4, #T_6b8ce_row36_col1, #T_6b8ce_row36_col4, #T_6b8ce_row37_col1, #T_6b8ce_row37_col4, #T_6b8ce_row38_col1, #T_6b8ce_row38_col4, #T_6b8ce_row39_col1, #T_6b8ce_row39_col4, #T_6b8ce_row40_col1, #T_6b8ce_row40_col4, #T_6b8ce_row41_col1, #T_6b8ce_row41_col4, #T_6b8ce_row42_col1, #T_6b8ce_row42_col4, #T_6b8ce_row43_col0, #T_6b8ce_row43_col1, #T_6b8ce_row43_col4, #T_6b8ce_row44_col1, #T_6b8ce_row44_col4, #T_6b8ce_row45_col1, #T_6b8ce_row45_col4, #T_6b8ce_row46_col1, #T_6b8ce_row46_col4, #T_6b8ce_row47_col1, #T_6b8ce_row47_col4, #T_6b8ce_row48_col1, #T_6b8ce_row48_col4, #T_6b8ce_row49_col1, #T_6b8ce_row49_col4, #T_6b8ce_row50_col1, #T_6b8ce_row50_col4, #T_6b8ce_row51_col1, #T_6b8ce_row51_col4, #T_6b8ce_row52_col1, #T_6b8ce
