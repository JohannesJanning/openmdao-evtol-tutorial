# %% [markdown]
# # eVTOL Multidisciplinary Design Optimization (MDO)
#
# **Objective: Minimize Total Operating Cost (TOC) per Flight [€]**
#
# Note on Binder Stability: JAX requires an initial "warm-up" period to compile the physics equations into machine code. If the kernel restarts on the first attempt, please run the cells again; subsequent runs will be significantly faster due to the persistent JAX compilation cache.

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Environment Setup

# %%
# Imports
import os
import sys
import time
import numpy as np
import src.parameters as parameters
from src.optimizer.eVTOL_group import eVTOLGroup
from src.analysis.evaluation_model import full_model_evaluation
import importlib
import src.analysis.evaluation_model as evaluation_model
from src.analysis.evaluation_model import write_results_to_excel, display_model_dashboard

# Binder-friendly JAX settings - JAX allows for automatic differentiation, just-in-time compilation, and GPU/TPU acceleration
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'
os.environ['JAX_ENABLE_X64'] = '1'

# Ensure local imports work in cloud notebooks
sys.path.append(os.getcwd())

import jax
import openmdao.api as om

# persistent jax compilation cache
ROOT = os.getcwd()
jax.config.update('jax_compilation_cache_dir', os.path.join(ROOT, 'jax_cache'))
try:
    jax.config.update('jax_enable_x64', True)
except Exception:
    pass



print('Environment and imports ready')
# Out:
# Environment and imports ready

# %% [markdown]
# ---

# %% [markdown]
# ## 2. OpenMDAO Optimizaiton Problem setup (building the problem)

# %%
# OpenMDAO Problem setup (build the problem)
prob = om.Problem(model=eVTOLGroup(parameters=parameters))

# %% [markdown]
# ### 2.1 Design Variables (define the design space)

# %%
# Design Variables (Independent variables) - creating a "component" that holds our design variables
# what the optimizer is allowed to touch to find the best design
# We provide "placeholder" initial values just to define the variables (they will be overwritten in the opt intializaiton by x(0))
iv = om.IndepVarComp()
iv.add_output('b', val=15.0) 
iv.add_output('c', val=1.0)
iv.add_output('r_cruise', val=1.0)
iv.add_output('r_hover', val=1.0)
iv.add_output('rho_bat', val=400.0)
iv.add_output('c_charge', val=2.0)
prob.model.add_subsystem('iv', iv, promotes=['*'])

# Design Variables bounds (and set scaling/pre-conditioning)
# ref: normalize variables of different magnitudes (e.g., 1.5m vs 400 Wh/kg) to a common 0 to 1 scale for smooth opt
prob.model.add_design_var('b', lower=6.0, upper=15.0, ref0=6.0, ref=15.0)
prob.model.add_design_var('c', lower=1.0, upper=2.5, ref0=1.0, ref=2.5)
prob.model.add_design_var('r_cruise', lower=0.6, upper=2.5, ref0=0.6, ref=2.5)
prob.model.add_design_var('r_hover', lower=0.6, upper=2.0, ref0=0.6, ref=2.0)
prob.model.add_design_var('rho_bat', lower=200.0, upper=300.0, ref0=200.0, ref=400.0)
prob.model.add_design_var('c_charge', lower=1.0, upper=4.0, ref0=1.0, ref=4.0)

# %% [markdown]
# ### 2.2 Constraints (setting boundaries)

# %%
# Constraints: Setting the constraints - creating a "component" that holds our constraints in OpenMDAO

# computation for the constraints component with initial values (these will be overwritten by the optimizer)
cons_comp = om.ExecComp('c1 = b - rotor_spacing',
                       b=15.0,
                       rotor_spacing=1.0)
prob.model.add_subsystem('cons_comp', cons_comp)

# connecting the constraint with the model
prob.model.connect('rotor_spacing', 'cons_comp.rotor_spacing')
prob.model.connect('b', 'cons_comp.b')

# The Enforcer: Constraints and design vars (scaling for the margins of the constraints)
prob.model.add_constraint('cons_comp.c1', lower=0.0, ref=1.0)
prob.model.add_constraint('vertiport_span', upper=15.0, ref=1.0)
prob.model.add_constraint('MTOM', upper=1500.0, ref=2000.0)
prob.model.add_constraint('V_cruise', upper=129.0, ref=100.0)
prob.model.add_constraint('V_climb', upper=129.0, ref=100.0)

# %% [markdown]
# ### 2.3 Objective (defining the goal)

# %%
# Optimization objective:
# negative ref (ref = -x) to maximize, positive ref (ref = x) to minimize

prob.model.add_objective('GWP_annual_ops', ref=50000.0)

# %% [markdown]
# ### 2.4 Optimizaiton Driver (setting up the engine)

# %%
# Driver setup (SLSQP) (Sequential Least Squares Programming) 
# gradient-based optimization algorithm that handles nonlinear problems with constraints effectively
# tol = tolerance for convergence (stop condition)
# disp = display optimization output, 
# declare_coloring = tells OpenMDAO to analyze which variables don't affect each other so it can calculate derivatives in parallel 
#   (enable sparsity pattern for efficient derivatives)

prob.driver = om.ScipyOptimizeDriver()
prob.driver.options['optimizer'] = 'SLSQP'
prob.driver.options['tol'] = 1e-6
prob.driver.options['disp'] = True
prob.driver.declare_coloring() if hasattr(prob.driver, 'declare_coloring') else None

# Initialization
# Gradient-based opt is iterative, 
# they need a starting point in the "design space" to begin searching for the optimum.
# the values are based on pre-SLSQP evelutionary optimizaiton and manual iteration

x0 = np.array([15.0, 1.7025, 1.5511, 1.6868, 400.0, 1.0], dtype=float)

# Finalize setup and initialize values
# prob.setup(): checks that all 'connect' statements actually go to real variables 
# - if made a typo in a variable name, this is where the code will crash
# prob.set_val(): initializes the values of the design variables to the starting point (x0) for the optimization

prob.setup()
prob.set_val('b', x0[0])
prob.set_val('c', x0[1])
prob.set_val('r_cruise', x0[2])
prob.set_val('r_hover', x0[3])
prob.set_val('rho_bat', x0[4])
prob.set_val('c_charge', x0[5])

print('Problem built and ready')
# Out:
# Problem built and ready

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Run the Optimization

# %%
# stopwatch for optimization time
t0 = time.time()

# prob.run_driver(): runs the optimization driver, which iteratively calls the model to evaluate the objective and constraints,
# and uses the results to update the design variables until convergence is achieved or an error occurs.

try:
    prob.run_driver()
except Exception as exc:
    print('Optimization failed:', exc)
    raise
t1 = time.time()
print(f'Elapsed (s): {t1-t0:.1f}')
# Out:
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 1607.86791 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 934.279776 0.581067495
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/utils/relevance.py:1234: OpenMDAOWarning:The top level group has a nonlinear solver that computes gradients, so the entire model will be included in the optimization iteration.
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/driver.py:700: DriverWarning:The following design variable initial conditions are out of their specified bounds:
#   rho_bat
#     val: [400.]
#     lower: 200.0
#     upper: 300.0
# Set the initial value of the design variable to a valid value or set the driver option['invalid_desvar_behavior'] to 'ignore'.
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 2 ; 9.31626644e-05 5.79417402e-08
# NL: Newton Converged
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/utils/coloring.py:428: DerivativesWarning:Coloring was deactivated.  Improvement of 0.0% was less than min allowed (5.0%).
# No coloring was computed successfully.
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 1 iterations
# NL: Newton 0 ; 105.950309 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 9.92881942 0.0937120382
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 2 ; 0.0450709467 0.000425397029
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 3 ; 2.94209642e-09 2.77686441e-11
# NL: Newton Converged
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 0 ; 513.256391 1
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 1 ; 646.880141 1.26034503
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 2 ; 70.7421009 0.137829947
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 3 ; 48.756413 0.0949942639
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 4 ; 37.5130548 0.0730883345
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 5 ; 55.5996689 0.10832728
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 6 ; 31.4254049 0.0612274985
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 7 ; 154.058226 0.300158418
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 8 ; 41.3488425 0.0805617685
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 9 ; 33.3663558 0.0650091385
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton 10 ; 90.1429637 0.175629501
# NL: Newton 11 ; 34020.6272 66.2838842
# NL: Newton 12 ; 88061.3705 171.573841
# NL: Newton 13 ; 43829.3673 85.394684
# NL: Newton 14 ; 243190.35 473.818454
# NL: Newton 15 ; 56950.795 110.959739
# NL: Newton 16 ; 28914.7282 56.3358366
# NL: Newton 17 ; 190672.675 371.495958
# NL: Newton 18 ; 88863.967 173.137575
# NL: Newton 19 ; 50260.6953 97.9251233
# NL: Newton 20 ; 35291.5146 68.76001
# NL: Newton 21 ; 60692.5529 118.24997
# NL: Newton 22 ; 27855.5027 54.272101
# Optimization failed: 'gwp' <class GWPComp>: Error calling compute(), float() argument must be a string or a real number, not 'complex'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/system.py:2992, in System._call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2991 try:
# -> 2992     yield
#    2993 except Exception:
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/explicitcomponent.py:345, in ExplicitComponent._compute_wrapper(self)
#     344 else:
# --> 345     self.compute(self._inputs, self._outputs)
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/src/optimizer/components/gwp_comp.py:92, in GWPComp.compute(self, inputs, outputs)
#      90 DOD = max(min(DOD, 1.0), eps)
# ---> 92 N_cycles_available = float(np.asarray(battery_cycle_life(DOD, C_avg, c_charge)))
#      93 N_cycles_available = max(N_cycles_available, 1.0)
#
# TypeError: float() argument must be a string or a real number, not 'complex'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 8
#       4 # prob.run_driver(): runs the optimization driver, which iteratively calls the model to evaluate the objective and constraints,
#       5 # and uses the results to update the design variables until convergence is achieved or an error occurs.
#       7 try:
# ----> 8     prob.run_driver()
#       9 except Exception as exc:
#      10     print('Optimization failed:', exc)
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/utils/hooks.py:369, in _HookDecorator.__call__(self, *args, **kwargs)
#     353 """
#     354 Run the function with any pre and post hooks.
#     355
#    (...)    366     The return value of the function.
#     367 """
#     368 self._run_hooks(self.pre_hooks, args, kwargs)
# --> 369 ret = self.func(*args, **kwargs)
#     370 self._run_hooks(self.post_hooks, args, kwargs, ret)
#     371 return ret
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/problem.py:728, in Problem.run_driver(self, case_prefix, reset_iter_counts)
#     724     record_model_options(self, self._run_counter)
#     726     model._clear_iprint()
# --> 728     return driver._run()
#     729 finally:
#     730     self._recording_iter.prefix = old_prefix
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/driver.py:821, in Driver._run(self)
#     819 with SaveOptResult(self):
#     820     with model._relevance.nonlinear_active('iter'):
# --> 821         self.result.success = not self.run()
#     823 if model._post_components:
#     824     with model._relevance.nonlinear_active('post'):
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/drivers/scipy_optimizer.py:487, in ScipyOptimizeDriver.run(self)
#     484     if prob.comm.rank != 0:
#     485         self.opt_settings['disp'] = False
# --> 487     result = minimize(self._objfunc, x_init,
#     488                       # args=(),
#     489                       method=opt,
#     490                       jac=jac,
#     491                       hess=hess,
#     492                       # hessp=None,
#     493                       bounds=bounds,
#     494                       constraints=constraints,
#     495                       tol=self.options['tol'],
#     496                       # callback=None,
#     497                       options=self.opt_settings)
#     498 elif opt == 'basinhopping':
#     499     from scipy.optimize import basinhopping
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/scipy/optimize/_minimize.py:796, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     793     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     794                            **options)
#     795 elif meth == 'slsqp':
# --> 796     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     797                           constraints, callback=callback, **options)
#     798 elif meth == 'trust-constr':
#     799     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     800                                        bounds, constraints,
#     801                                        callback=callback, **options)
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/scipy/optimize/_slsqp_py.py:525, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, workers, **unknown_options)
#     523 if state_dict['mode'] == 1:  # objective and constraint evaluation required
#     524     fx = sf.fun(x)
# --> 525     _eval_constraint(d, x, cons, m, meq)
#     527 if state_dict['mode'] == -1:  # gradient evaluation required
#     528     g = sf.grad(x)
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/scipy/optimize/_slsqp_py.py:587, in _eval_constraint(d, x, cons, m, meq)
#     585 row = meq
#     586 for con in cons['ineq']:
# --> 587     temp = np.atleast_1d(con['fun'](x, *con['args'])).ravel()
#     588     d[row:row + len(temp)] = temp
#     589     row += len(temp)
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/utils/class_util.py:82, in WeakMethodWrapper.__call__(self, *args, **kwargs)
#      66 def __call__(self, *args, **kwargs):
#      67     """
#      68     Call the named method on the object.
#      69
#    (...)     80         The return value of the wrapped method called with the given args.
#      81     """
# ---> 82     return getattr(self._ref(), self.__name__)(*args, **kwargs)
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/drivers/scipy_optimizer.py:706, in ScipyOptimizeDriver._confunc(self, x_new, name, dbl, idx)
#     683 """
#     684 Return the value of the constraint function requested in args.
#     685
#    (...)    703     Value of the constraint function.
#     704 """
#     705 if self._exc_info is not None:
# --> 706     self._reraise()
#     708 cons = self._con_cache
#     709 meta = self._cons[name]
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/driver.py:2046, in Driver._reraise(self)
#    2044 exc_info = self._exc_info
#    2045 self._exc_info = None  # clear since we're done with it
# -> 2046 raise exc_info[1].with_traceback(exc_info[2])
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/drivers/scipy_optimizer.py:632, in ScipyOptimizeDriver._objfunc(self, x_new)
#     630     self.iter_count += 1
#     631     with model._relevance.nonlinear_active('iter'):
# --> 632         self._run_solve_nonlinear()
#     634 # Get the objective function evaluations
#     635 for obj in self.get_objective_values().values():
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/driver.py:179, in DriverResult.track_stats.<locals>._track_time.<locals>.wrapper(*args, **kwargs)
#     176 @functools.wraps(func)
#     177 def wrapper(*args, **kwargs):
#     178     start_time = time.perf_counter()
# --> 179     ret = func(*args, **kwargs)
#     180     end_time = time.perf_counter()
#     181     result = args[0].result
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/driver.py:1304, in Driver._run_solve_nonlinear(self)
#    1302 @DriverResult.track_stats(kind='model')
#    1303 def _run_solve_nonlinear(self):
# -> 1304     return self._problem().model.run_solve_nonlinear()
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/system.py:5151, in System.run_solve_nonlinear(self)
#    5145 """
#    5146 Compute outputs.
#    5147
#    5148 This calls _solve_nonlinear, but with the model assumed to be in an unscaled state.
#    5149 """
#    5150 with self._scaled_context_all():
# -> 5151     self._solve_nonlinear()
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/group.py:3845, in Group._solve_nonlinear(self)
#    3843 with Recording(name + '._solve_nonlinear', self.iter_count, self):
#    3844     with self._relevance.active(self._nonlinear_solver.use_relevance()):
# -> 3845         self._nonlinear_solver._solve_with_cache_check()
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/solvers/solver.py:979, in NonlinearSolver._solve_with_cache_check(self)
#     977         raise
#     978 else:
# --> 979     self.solve()
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/solvers/solver.py:741, in NonlinearSolver.solve(self)
#     739 if self.options['debug_print']:
#     740     self._print_exc_debug_info()
# --> 741 raise err
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/solvers/solver.py:737, in NonlinearSolver.solve(self)
#     733 """
#     734 Run the solver.
#     735 """
#     736 try:
# --> 737     self._solve()
#     738 except Exception as err:
#     739     if self.options['debug_print']:
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/solvers/solver.py:827, in NonlinearSolver._solve(self)
#     824     self._single_iteration()
#     826 self._iter_count += 1
# --> 827 self._run_apply()
#     828 norm = self._iter_get_norm()
#     830 # Save the norm values in the context manager so they can also be recorded.
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/solvers/nonlinear/newton.py:133, in NewtonSolver._run_apply(self)
#     130 system._owns_approx_jac = False
#     132 try:
# --> 133     system._apply_nonlinear()
#     134 finally:
#     135     self._recording_iter.pop()
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/group.py:3833, in Group._apply_nonlinear(self)
#    3831 # Apply recursion
#    3832 for subsys in self._relevance.filter(self._subsystems_myproc):
# -> 3833     subsys._apply_nonlinear()
#    3835 self.iter_count_apply += 1
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/explicitcomponent.py:358, in ExplicitComponent._apply_nonlinear(self)
#     356 # Sign of the residual is minus the sign of the output vector.
#     357 residuals *= -1.0
# --> 358 self._compute_wrapper()
#     359 residuals += outputs
#     360 outputs -= residuals
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/explicitcomponent.py:325, in ExplicitComponent._compute_wrapper(self)
#     321 def _compute_wrapper(self):
#     322     """
#     323     Call compute based on the value of the "run_root_only" option.
#     324     """
# --> 325     with self._call_user_function('compute'):
#     326         if self._run_root_only():
#     327             if self.comm.rank == 0:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/system.py:2998, in System._call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2996         raise
#    2997     else:
# -> 2998         raise err_type(
#    2999             f"{self.msginfo}: Error calling {fname}(), {err}").with_traceback(trace)
#    3000 finally:
#    3001     self._inputs.read_only = False
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/system.py:2992, in System._call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2989 self._residuals.read_only = protect_residuals
#    2991 try:
# -> 2992     yield
#    2993 except Exception:
#    2994     err_type, err, trace = sys.exc_info()
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/explicitcomponent.py:345, in ExplicitComponent._compute_wrapper(self)
#     342     self.compute(self._inputs, self._outputs,
#     343                  self._discrete_inputs, self._discrete_outputs)
#     344 else:
# --> 345     self.compute(self._inputs, self._outputs)
#
# File ~/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/src/optimizer/components/gwp_comp.py:92, in GWPComp.compute(self, inputs, outputs)
#      89 DOD = float(np.asarray(depth_of_discharge(E_trip, E_batt_design_Wh)))
#      90 DOD = max(min(DOD, 1.0), eps)
# ---> 92 N_cycles_available = float(np.asarray(battery_cycle_life(DOD, C_avg, c_charge)))
#      93 N_cycles_available = max(N_cycles_available, 1.0)
#      95 # number of battery packs required annually
#
# TypeError: 'gwp' <class GWPComp>: Error calling compute(), float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Data Extraction

# %%
# - sval: A helper to safely extract scalar values from the OpenMDAO solver.
# - b_opt...c_charge_opt: Capturing the "Winning Design" into standard variables.
# - Print: Displaying the final Design Vector for the optimized eVTOL

def sval(name):
    try:
        return float(np.asarray(prob.get_val(name)).item())
    except Exception:
        return None

b_opt = sval('b')
c_opt = sval('c')
r_cruise_opt = sval('r_cruise')
r_hover_opt = sval('r_hover')
rho_bat_opt = sval('rho_bat')
c_charge_opt = sval('c_charge')

print('Optimal design vector:')
print([b_opt, c_opt, r_cruise_opt, r_hover_opt, rho_bat_opt, c_charge_opt])
# Out:
# Optimal design vector:
# [11.894705668034362, 1.0, 1.0018407173043036, 1.6868749999999997, 300.0, 2.0058237048710916]

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Design Results

# %%
# 1. full_model_evaluation: Generates a deep-dive dataset for the winning design.
# 2. baseline_vector: Used to calculate "Optimization Gain" (Best vs. Standard).
# 3. Excel & Dashboard: Exports results for stakeholders and displays key performance metrics.

# post-optimization evaluation to get the full set of performance metrics for the optimized design
model_results, comparison_table = full_model_evaluation(
    b_opt, c_opt, r_cruise_opt, r_hover_opt, rho_bat_opt, c_charge_opt, parameters
)

# Define your baseline for the comparison logic
baseline_vector = [9.874446571073564, 1.0, 0.8561370588805344, 1.394907761845594, 399.99999999999994, 2.0253538731700154]

# Generates a detailed Excel report containing the full model
importlib.reload(evaluation_model)
out_path, df_results = write_results_to_excel(
    results_dict=model_results,
    comparison_list=comparison_table,
    mode='TOC',
    filename='optimized_results_TOC.xlsx',
    baseline=baseline_vector
)

# visual dashboard for the optimized design
print("-" * 30)
print("  OPTIMIZED DESIGN DASHBOARD")
print("-" * 30)
# Make sure display_model_dashboard is updated to handle the 'baseline' argument
display_model_dashboard(model_results, baseline=baseline_vector)
# Out:
# Results written to: src/results/TOC/optimized_results_TOC.xlsx
# ------------------------------
#   OPTIMIZED DESIGN DASHBOARD
# ------------------------------
# <style type="text/css">
# #T_91987 th {
#   background-color: #f2f2f2;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #666;
#   text-align: center;
# }
# #T_91987 td.row0 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row1 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row2 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row3 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row4 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row5 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row6 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row7 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row8 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row9 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row10 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row11 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row12 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row13 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row14 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row15 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row16 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row17 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row18 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row19 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row20 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row21 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row22 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row23 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row24 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row25 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row26 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row27 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row28 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row29 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row30 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row31 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row32 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row33 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row34 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row35 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row36 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row37 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row38 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row39 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row40 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row41 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row42 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row43 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row44 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row45 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row46 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row47 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row48 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row49 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row50 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row51 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row52 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row53 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row54 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row55 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row56 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row57 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row58 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row59 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row60 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row61 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row62 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row63 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row64 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row65 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row66 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row67 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row68 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row69 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row70 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row71 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row72 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row73 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row74 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row75 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row76 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row77 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row78 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row79 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row80 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row81 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row82 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row83 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row84 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row85 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row86 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row87 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row88 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row89 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row90 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row91 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row92 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row93 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row94 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row95 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row96 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row97 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row98 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row99 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row100 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row101 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row102 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row103 {
#   border-top: 1px solid #eee;
# }
# #T_91987 td.row104 {
#   border-top: 3px solid #444;
# }
# #T_91987 td.row105 {
#   border-top: 1px solid #eee;
# }
# #T_91987_row0_col0, #T_91987_row0_col1, #T_91987_row0_col4, #T_91987_row1_col1, #T_91987_row1_col4, #T_91987_row2_col1, #T_91987_row2_col4, #T_91987_row3_col1, #T_91987_row3_col4, #T_91987_row4_col1, #T_91987_row4_col4, #T_91987_row5_col1, #T_91987_row5_col4, #T_91987_row6_col0, #T_91987_row6_col1, #T_91987_row6_col4, #T_91987_row7_col1, #T_91987_row7_col4, #T_91987_row8_col1, #T_91987_row8_col4, #T_91987_row9_col1, #T_91987_row9_col4, #T_91987_row10_col1, #T_91987_row10_col4, #T_91987_row11_col1, #T_91987_row11_col4, #T_91987_row12_col1, #T_91987_row12_col4, #T_91987_row13_col1, #T_91987_row13_col4, #T_91987_row14_col1, #T_91987_row14_col4, #T_91987_row15_col0, #T_91987_row15_col1, #T_91987_row15_col4, #T_91987_row16_col1, #T_91987_row16_col4, #T_91987_row17_col1, #T_91987_row17_col4, #T_91987_row18_col1, #T_91987_row18_col4, #T_91987_row19_col0, #T_91987_row19_col1, #T_91987_row19_col4, #T_91987_row20_col1, #T_91987_row20_col4, #T_91987_row21_col1, #T_91987_row21_col4, #T_91987_row22_col1, #T_91987_row22_col4, #T_91987_row23_col1, #T_91987_row23_col4, #T_91987_row24_col1, #T_91987_row24_col4, #T_91987_row25_col1, #T_91987_row25_col4, #T_91987_row26_col1, #T_91987_row26_col4, #T_91987_row27_col1, #T_91987_row27_col4, #T_91987_row28_col1, #T_91987_row28_col4, #T_91987_row29_col1, #T_91987_row29_col4, #T_91987_row30_col1, #T_91987_row30_col4, #T_91987_row31_col1, #T_91987_row31_col4, #T_91987_row32_col0, #T_91987_row32_col1, #T_91987_row32_col4, #T_91987_row33_col1, #T_91987_row33_col4, #T_91987_row34_col1, #T_91987_row34_col4, #T_91987_row35_col0, #T_91987_row35_col1, #T_91987_row35_col4, #T_91987_row36_col1, #T_91987_row36_col4, #T_91987_row37_col1, #T_91987_row37_col4, #T_91987_row38_col1, #T_91987_row38_col4, #T_91987_row39_col1, #T_91987_row39_col4, #T_91987_row40_col1, #T_91987_row40_col4, #T_91987_row41_col1, #T_91987_row41_col4, #T_91987_row42_col1, #T_91987_row42_col4, #T_91987_row43_col0, #T_91987_row43_col1, #T_91987_row43_col4, #T_91987_row44_col1, #T_91987_row44_col4, #T_91987_row45_col1, #T_91987_row45_col4, #T_91987_row46_col1, #T_91987_row46_col4, #T_91987_row47_col1, #T_91987_row47_col4, #T_91987_row48_col1, #T_91987_row48_col4, #T_91987_row49_col1, #T_91987_row49_col4, #T_91987_row50_col1, #T_91987_row50_col4, #T_91987_row51_col1, #T_91987_row51_col4, #T_91987_row52_col1, #T_91987
