# %% [markdown]
# # TOC Optimization (Notebook)
#
# Problem Formulation: run an OpenMDAO optimization minimizing TOC (Total Operating Cost per flight) and save a post-optimization Excel report.

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Environment Setup

# %%
# Imports
import os
import sys
import time
import numpy as np
import src.parameters as parameters
from src.optimizer.eVTOL_group import eVTOLGroup
from src.analysis.evaluation_model import full_model_evaluation
import importlib
import src.analysis.evaluation_model as evaluation_model
from src.analysis.evaluation_model import write_results_to_excel, display_model_dashboard

# Binder-friendly JAX settings - JAX allows for automatic differentiation, just-in-time compilation, and GPU/TPU acceleration
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'
os.environ['JAX_ENABLE_X64'] = '1'

# Ensure local imports work in cloud notebooks
sys.path.append(os.getcwd())

import jax
import openmdao.api as om

# persistent jax compilation cache
ROOT = os.getcwd()
jax.config.update('jax_compilation_cache_dir', os.path.join(ROOT, 'jax_cache'))
try:
    jax.config.update('jax_enable_x64', True)
except Exception:
    pass



print('Environment and imports ready')
# Out:
# Environment and imports ready

# %% [markdown]
# ---

# %% [markdown]
# ## 2. OpenMDAO Optimizaiton Problem setup (building the problem)

# %%
# OpenMDAO Problem setup (build the problem)
prob = om.Problem(model=eVTOLGroup(parameters=parameters))

# %% [markdown]
# ### Design Variables (define the design space)

# %%
# Design Variables (Independent variables) - creating a "component" that holds our design variables
# what the optimizer is allowed to touch to find the best design
# We provide "placeholder" initial values just to define the variables (they will be overwritten in the opt intializaiton by x(0))
iv = om.IndepVarComp()
iv.add_output('b', val=15.0) 
iv.add_output('c', val=1.0)
iv.add_output('r_cruise', val=1.0)
iv.add_output('r_hover', val=1.0)
iv.add_output('rho_bat', val=400.0)
iv.add_output('c_charge', val=2.0)
prob.model.add_subsystem('iv', iv, promotes=['*'])

# Design Variables bounds (and set scaling/pre-conditioning)
# ref: normalize variables of different magnitudes (e.g., 1.5m vs 400 Wh/kg) to a common 0 to 1 scale for smooth opt
prob.model.add_design_var('b', lower=6.0, upper=15.0, ref0=6.0, ref=15.0)
prob.model.add_design_var('c', lower=1.0, upper=2.5, ref0=1.0, ref=2.5)
prob.model.add_design_var('r_cruise', lower=0.6, upper=2.5, ref0=0.6, ref=2.5)
prob.model.add_design_var('r_hover', lower=0.6, upper=2.0, ref0=0.6, ref=2.0)
prob.model.add_design_var('rho_bat', lower=200.0, upper=400.0, ref0=200.0, ref=400.0)
prob.model.add_design_var('c_charge', lower=1.0, upper=4.0, ref0=1.0, ref=4.0)

# %% [markdown]
# ### Constraints (setting boundaries)

# %%
# Constraints: Setting the constraints - creating a "component" that holds our constraints in OpenMDAO
cons_expr = (
    'c1 = b - rotor_spacing',
    'c2 = 15.0 - vertiport_span',
    'c3 = 5700.0 - MTOM',
    'c4 = 129.0 - V_cruise',
    'c5 = 129.0 - V_climb',
)

# computation for the constraints component with initial values (these will be overwritten by the optimizer)
cons_comp = om.ExecComp('\n'.join(cons_expr),
                       b=15.0,
                       rotor_spacing=1.0,
                       vertiport_span=1.0,
                       MTOM=1500.0,
                       V_cruise=50.0,
                       V_climb=10.0)

prob.model.add_subsystem('cons_comp', cons_comp)

prob.model.connect('rotor_spacing', 'cons_comp.rotor_spacing')
prob.model.connect('vertiport_span', 'cons_comp.vertiport_span')
prob.model.connect('b', 'cons_comp.b')
prob.model.connect('mtom.MTOM', 'cons_comp.MTOM')
prob.model.connect('V_cruise', 'cons_comp.V_cruise')
prob.model.connect('V_climb', 'cons_comp.V_climb')

# The Enforcer: Constraints and design vars (scaling for the margins of the constraints)
prob.model.add_constraint('cons_comp.c1', lower=0.0, ref=1.0)
prob.model.add_constraint('cons_comp.c2', lower=0.0, ref=1.0)
prob.model.add_constraint('cons_comp.c3', lower=0.0, ref=1.0)
prob.model.add_constraint('cons_comp.c4', lower=0.0, ref=1.0)
prob.model.add_constraint('cons_comp.c5', lower=0.0, ref=1.0)

# %% [markdown]
# ### Objective (defining the goal)

# %%
# Objective: minimize TOC per flight (TOC_flight)
prob.model.add_objective('TOC_flight', ref=200.0)

# %% [markdown]
# ### Optimizaiton Driver (setting up the engine)

# %%
# Driver setup (SLSQP) (Sequential Least Squares Programming) 
# gradient-based optimization algorithm that handles nonlinear problems with constraints effectively
# tol = tolerance for convergence (stop condition)
# disp = display optimization output, 
# declare_coloring = tells OpenMDAO to analyze which variables don't affect each other so it can calculate derivatives in parallel 
#   (enable sparsity pattern for efficient derivatives)

prob.driver = om.ScipyOptimizeDriver()
prob.driver.options['optimizer'] = 'SLSQP'
prob.driver.options['tol'] = 1e-6
prob.driver.options['disp'] = True
prob.driver.declare_coloring() if hasattr(prob.driver, 'declare_coloring') else None

# Initialization
# Gradient-based opt is iterative, 
# they need a starting point in the "design space" to begin searching for the optimum.
# the values are based on pre-SLSQP evelutionary optimizaiton and manual iteration

x0 = np.array([15.0, 1.7025, 1.5511, 1.6868, 400.0, 1.0], dtype=float)

# Finalize setup and initialize values
# prob.setup(): checks that all 'connect' statements actually go to real variables 
# - if made a typo in a variable name, this is where the code will crash
# prob.set_val(): initializes the values of the design variables to the starting point (x0) for the optimization

prob.setup()
prob.set_val('b', x0[0])
prob.set_val('c', x0[1])
prob.set_val('r_cruise', x0[2])
prob.set_val('r_hover', x0[3])
prob.set_val('rho_bat', x0[4])
prob.set_val('c_charge', x0[5])

print('Problem built and ready')
# Out:
# Problem built and ready

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Run the Optimization (ignite the engine)

# %%
# stopwatch for optimization time
t0 = time.time()

# prob.run_driver(): runs the optimization driver, which iteratively calls the model to evaluate the objective and constraints,
# and uses the results to update the design variables until convergence is achieved or an error occurs.

try:
    prob.run_driver()
except Exception as exc:
    print('Optimization failed:', exc)
    raise
t1 = time.time()
print(f'Elapsed (s): {t1-t0:.1f}')
# Out:
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/utils/relevance.py:1234: OpenMDAOWarning:The top level group has a nonlinear solver that computes gradients, so the entire model will be included in the optimization iteration.
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/driver.py:1276: DriverWarning:ScipyOptimizeDriver: constraint(s) ['cons_comp.c2', 'cons_comp.c3', 'cons_comp.c4', 'cons_comp.c5'] do not depend on any design variables. Please check your problem formulation.
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
#
# Jacobian shape: (6, 6)  (72.22% nonzero)
# FWD solves: 0   REV solves: 5
# Total colors vs. total size: 5 vs 6  (16.67% improvement)
#
# Sparsity computed using tolerance: 1e-25.
# Dense total jacobian for Problem 'problem' was computed 3 times.
# Time to compute sparsity:   0.2276 sec
# Time to compute coloring:   0.0017 sec
# Memory to compute coloring:   0.1875 MB
# Coloring created on: 2026-03-07 16:40:31
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 1 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 1 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 1 iterations
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/.venv/lib/python3.11/site-packages/openmdao/core/total_jac.py:1670: DerivativesWarning:The following constraints or objectives cannot be impacted by the design variables of the problem at the current design point:
#   cons_comp.c2, inds=[0]
#   cons_comp.c3, inds=[0]
#   cons_comp.c4, inds=[0]
#   cons_comp.c5, inds=[0]
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 1 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 1 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 1 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 1 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 1 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 1 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# +
# +  ====
# +  mtom
# +  ====
# +  NL: Newton Converged in 0 iterations
# NL: Newton Converged in 2 iterations
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.46829086612960574
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization Complete
# -----------------------------------
# Elapsed (s): 6.5

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Data Extraction

# %%
# - sval: A helper to safely extract scalar values from the OpenMDAO solver.
# - b_opt...c_charge_opt: Capturing the "Winning Design" into standard variables.
# - Print: Displaying the final Design Vector for the optimized eVTOL

def sval(name):
    try:
        return float(np.asarray(prob.get_val(name)).item())
    except Exception:
        return None

b_opt = sval('b')
c_opt = sval('c')
r_cruise_opt = sval('r_cruise')
r_hover_opt = sval('r_hover')
rho_bat_opt = sval('rho_bat')
c_charge_opt = sval('c_charge')

print('Optimal design vector:')
print([b_opt, c_opt, r_cruise_opt, r_hover_opt, rho_bat_opt, c_charge_opt])
# Out:
# Optimal design vector:
# [9.87549492390286, 1.0000000000000002, 0.8547152121491244, 1.395082487317143, 400.0, 2.0210037764649207]

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Design Results

# %%
# 1. full_model_evaluation: Generates a deep-dive dataset for the winning design.
# 2. baseline_vector: Used to calculate "Optimization Gain" (Best vs. Standard).
# 3. Excel & Dashboard: Exports results for stakeholders and displays key performance metrics.

model_results, comparison_table = full_model_evaluation(
    b_opt, c_opt, r_cruise_opt, r_hover_opt, rho_bat_opt, c_charge_opt, parameters
)

# Define your baseline for the comparison logic
baseline_vector = [9.875494923902856, 1.0000000000000004, 0.8547152121491242, 1.3950824873171428, 400.0, 2.021003776464922]

# 3. STORAGE & EXPORT

importlib.reload(evaluation_model)


# Save to Excel - Pass the comparison_table here so the Excel has the data
out_path, df_results = write_results_to_excel(
    results_dict=model_results,
    comparison_list=comparison_table,
    mode='TOC',
    filename='optimized_results_TOC.xlsx',
    baseline=baseline_vector
)

# 4. VISUAL DASHBOARD
print("-" * 30)
print("  OPTIMIZED DESIGN DASHBOARD")
print("-" * 30)
# Make sure display_model_dashboard is updated to handle the 'baseline' argument
display_model_dashboard(model_results, baseline=baseline_vector)

# 5. DOWNLOAD LINK
from IPython.display import FileLink, display as ipy_display
if os.path.exists(out_path):
    print("\nDownload full Excel report:")
    ipy_display(FileLink(out_path))
# Out:
# Results written to: src/results/TOC/optimized_results_TOC.xlsx
# ------------------------------
#   OPTIMIZED DESIGN DASHBOARD
# ------------------------------
# <style type="text/css">
# #T_f01b5 th {
#   background-color: #f2f2f2;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #666;
#   text-align: center;
# }
# #T_f01b5 td.row0 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row1 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row2 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row3 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row4 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row5 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row6 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row7 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row8 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row9 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row10 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row11 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row12 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row13 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row14 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row15 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row16 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row17 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row18 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row19 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row20 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row21 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row22 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row23 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row24 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row25 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row26 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row27 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row28 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row29 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row30 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row31 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row32 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row33 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row34 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row35 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row36 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row37 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row38 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row39 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row40 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row41 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row42 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row43 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row44 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row45 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row46 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row47 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row48 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row49 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row50 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row51 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row52 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row53 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row54 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row55 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row56 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row57 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row58 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row59 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row60 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row61 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row62 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row63 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row64 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row65 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row66 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row67 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row68 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row69 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row70 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row71 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row72 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row73 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row74 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row75 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row76 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row77 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row78 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row79 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row80 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row81 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row82 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row83 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row84 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row85 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row86 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row87 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row88 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row89 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row90 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row91 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row92 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row93 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row94 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row95 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row96 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row97 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row98 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row99 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row100 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row101 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row102 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row103 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5 td.row104 {
#   border-top: 3px solid #444;
# }
# #T_f01b5 td.row105 {
#   border-top: 1px solid #eee;
# }
# #T_f01b5_row0_col0, #T_f01b5_row0_col1, #T_f01b5_row0_col4, #T_f01b5_row1_col1, #T_f01b5_row1_col4, #T_f01b5_row2_col1, #T_f01b5_row2_col4, #T_f01b5_row3_col1, #T_f01b5_row3_col4, #T_f01b5_row4_col1, #T_f01b5_row4_col4, #T_f01b5_row5_col1, #T_f01b5_row5_col4, #T_f01b5_row6_col0, #T_f01b5_row6_col1, #T_f01b5_row6_col4, #T_f01b5_row7_col1, #T_f01b5_row7_col4, #T_f01b5_row8_col1, #T_f01b5_row8_col4, #T_f01b5_row9_col1, #T_f01b5_row9_col4, #T_f01b5_row10_col1, #T_f01b5_row10_col4, #T_f01b5_row11_col1, #T_f01b5_row11_col4, #T_f01b5_row12_col1, #T_f01b5_row12_col4, #T_f01b5_row13_col1, #T_f01b5_row13_col4, #T_f01b5_row14_col1, #T_f01b5_row14_col4, #T_f01b5_row15_col0, #T_f01b5_row15_col1, #T_f01b5_row15_col4, #T_f01b5_row16_col1, #T_f01b5_row16_col4, #T_f01b5_row17_col1, #T_f01b5_row17_col4, #T_f01b5_row18_col1, #T_f01b5_row18_col4, #T_f01b5_row19_col0, #T_f01b5_row19_col1, #T_f01b5_row19_col4, #T_f01b5_row20_col1, #T_f01b5_row20_col4, #T_f01b5_row21_col1, #T_f01b5_row21_col4, #T_f01b5_row22_col1, #T_f01b5_row22_col4, #T_f01b5_row23_col1, #T_f01b5_row23_col4, #T_f01b5_row24_col1, #T_f01b5_row24_col4, #T_f01b5_row25_col1, #T_f01b5_row25_col4, #T_f01b5_row26_col1, #T_f01b5_row26_col4, #T_f01b5_row27_col1, #T_f01b5_row27_col4, #T_f01b5_row28_col1, #T_f01b5_row28_col4, #T_f01b5_row29_col1, #T_f01b5_row29_col4, #T_f01b5_row30_col1, #T_f01b5_row30_col4, #T_f01b5_row31_col1, #T_f01b5_row31_col4, #T_f01b5_row32_col0, #T_f01b5_row32_col1, #T_f01b5_row32_col4, #T_f01b5_row33_col1, #T_f01b5_row33_col4, #T_f01b5_row34_col1, #T_f01b5_row34_col4, #T_f01b5_row35_col0, #T_f01b5_row35_col1, #T_f01b5_row35_col4, #T_f01b5_row36_col1, #T_f01b5_row36_col4, #T_f01b5_row37_col1, #T_f01b5_row37_col4, #T_f01b5_row38_col1, #T_f01b5_row38_col4, #T_f01b5_row39_col1, #T_f01b5_row39_col4, #T_f01b5_row40_col1, #T_f01b5_row40_col4, #T_f01b5_row41_col1, #T_f01b5_row41_col4, #T_f01b5_row42_col1, #T_f01b5_row42_col4, #T_f01b5_row43_col0, #T_f01b5_row43_col1, #T_f01b5_row43_col4, #T_f01b5_row44_col1, #T_f01b5_row44_col4, #T_f01b5_row45_col1, #T_f01b5_row45_col4, #T_f01b5_row46_col1, #T_f01b5_row46_col4, #T_f01b5_row47_col1, #T_f01b5_row47_col4, #T_f01b5_row48_col1, #T_f01b5_row48_col4, #T_f01b5_row49_col1, #T_f01b5_row49_col4, #T_f01b5_row50_col1, #T_f01b5_row50_col4, #T_f01b5_row51_col1, #T_f01b5_row51_col4, #T_f01b5_row52_col1, #T_f01b5
# Download full Excel report:
# /Users/johannesjanning/Library/CloudStorage/Dropbox/Mac (3)/Documents/VSC/eVTOL_OpenMDAO_v3_notebook_building/src/results/TOC/optimized_results_TOC.xlsx
